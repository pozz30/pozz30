# %% [markdown]
# 필요 패키지 불러오기

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# 데이터 불러오기

# %%
train_data=pd.read_csv('drive/MyDrive/data/train.csv')
test_data=pd.read_csv('drive/MyDrive/data/test.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# •	Survived : 0 = 사망, 1 = 생존
# •	Pclass : 1 = 1등석, 2 = 2등석, 3 = 3등석
# •	Sex : male = 남성, female = 여성
# •	Age : 나이
# •	SibSp : 타이타닉 호에 동승한 자매 / 배우자의 수
# •	Parch : 타이타닉 호에 동승한 부모 / 자식의 수
# •	Ticket : 티켓 번호
# •	Fare : 승객 요금
# •	Cabin : 방 호수
# •	Embarked : 탑승지, C = 셰르부르, Q = 퀸즈타운, S = 사우샘프턴

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 성별로 분류하여 Initial을 확인
# crosstab은 범주형 데이터를 기준으로 개수 파악에 사용

# %%
train_data['Initial']= train_data.Name.str.extract('([A-Za-z]+)\.')

test_data['Initial']= test_data.Name.str.extract('([A-Za-z]+)\.')

# A-Z 또는 a-z 사이에 있고 .(점)이 오는 문자열을 찾는다. 중간에 위치한 title 찾는 코드
# 성별로 분류하여 Initial을 확인

pd.crosstab(train_data.Initial,train_data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_cd885_row0_col0, #T_cd885_row0_col1, #T_cd885_row0_col3, #T_cd885_row0_col4, #T_cd885_row0_col5, #T_cd885_row0_col7, #T_cd885_row0_col8, #T_cd885_row0_col12, #T_cd885_row0_col15, #T_cd885_row0_col16, #T_cd885_row1_col2, #T_cd885_row1_col6, #T_cd885_row1_col9, #T_cd885_row1_col10, #T_cd885_row1_col11, #T_cd885_row1_col13, #T_cd885_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_cd885_row0_col2, #T_cd885_row0_col6, #T_cd885_row0_col9, #T_cd885_row0_col10, #T_cd885_row0_col11, #T_cd885_row0_col13, #T_cd885_row0_col14, #T_cd885_row1_col0, #T_cd885_row1_col1, #T_cd885_row1_col3, #T_cd885_row1_col4, #T_cd885_row1_col5, #T_cd885_row1_col7, #T_cd885_row1_col8, #T_cd885_row1_col12, #T_cd885_row1_col15, #T_cd885_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cd885_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th class="col_heading level0 col0" >Capt</th>
#       <th class="col_heading level0 col1" >Col</th>
#       <th class="col_heading level0 col2" >Countess</th>
#       <th class="col_heading level0 col3" >Don</th>
#       <th class="col_heading level0 col4" >Dr</th>
#       <th class="col_heading level0 col5" >Jonkheer</th>
#       <th class="col_heading level0 col6" >Lady</th>
#       <th class="col_heading level0 col7" >Major</th>
#       <th class="col_heading level0 col8" >Master</th>
#       <th class="col_heading level0 col9" >Miss</th>
#       <th class="col_heading level0 col10" >Mlle</th>
#       <th class="col_heading level0 col11" >Mme</th>
#       <th class="col_heading level0 col12" >Mr</th>
#       <th class="col_heading level0 col13" >Mrs</th>
#       <th class="col_heading level0 col14" >Ms</th>
#       <th class="col_heading level0 col15" >Rev</th>
#       <th class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd885_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_cd885_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_cd885_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cd885_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_cd885_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cd885_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_cd885_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_cd885_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cd885_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_cd885_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_cd885_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_cd885_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_cd885_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_cd885_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_cd885_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_cd885_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_cd885_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_cd885_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cd885_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_cd885_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_cd885_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_cd885_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_cd885_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_cd885_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_cd885_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_cd885_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_cd885_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_cd885_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_cd885_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_cd885_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_cd885_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_cd885_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_cd885_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_cd885_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_cd885_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_cd885_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked Initial
# 886    male  27.0      0      0      211536  13.00   NaN        S     Rev
# 887  female  19.0      0      0      112053  30.00   B42        S    Miss
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S    Miss
# 889    male  26.0      0      0      111369  30.00  C148        C      Mr
# 890    male  32.0      0      0      370376   7.75   NaN        Q      Mr

# %% [markdown]
# 이니셜별로 평균을 사용하기위하여 유의미 하지 않은 이니셜은 유의미한 이니셜로 치환함

# %%
# 라벨(title)을 유의미한 데이터로 대체한다.

train_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                              ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
test_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                             ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked Initial
# 886    male  27.0      0      0      211536  13.00   NaN        S   Other
# 887  female  19.0      0      0      112053  30.00   B42        S    Miss
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S    Miss
# 889    male  26.0      0      0      111369  30.00  C148        C      Mr
# 890    male  32.0      0      0      370376   7.75   NaN        Q      Mr

# %%
# 라벨에 따라 나이의 평균 값을 나타낸다.

train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %% [markdown]
# 나이의 결측값을 이니셜의 평균 나이로 대체

# %%
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Other'),'Age']=46

test_data.loc[(test_data.Age.isnull())&(test_data.Initial=='Mr'),'Age'] = 33
test_data.loc[(test_data.Age.isnull())&(test_data.Initial=='Mrs'),'Age'] = 36
test_data.loc[(test_data.Age.isnull())&(test_data.Initial=='Master'),'Age'] = 5
test_data.loc[(test_data.Age.isnull())&(test_data.Initial=='Miss'),'Age'] = 22
test_data.loc[(test_data.Age.isnull())&(test_data.Initial=='Other'),'Age'] = 46

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Initial          0
# dtype: int64

# %% [markdown]
# embarked이 2개 결측값은 가장 많은 'S'로 대체 및 확인

# %%
train_data['Embarked'].fillna('S',inplace=True)
train_data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# 나이는 연속형 데이터로 그냥 사용 해도 되나, 구간을 나누어 조금더 뚜렸한 패턴을 보이도록 해본다.

# %%
# Age를 그룹화하기

train_data['Age_band']=0
train_data.loc[train_data['Age']<=16,'Age_band']=0
train_data.loc[(train_data['Age']>16)&(train_data['Age']<=32),'Age_band']=1
train_data.loc[(train_data['Age']>32)&(train_data['Age']<=48),'Age_band']=2
train_data.loc[(train_data['Age']>48)&(train_data['Age']<=64),'Age_band']=3
train_data.loc[train_data['Age']>64,'Age_band']=4

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0         A/5 21171   7.2500   NaN        S      Mr         1
# 1      0          PC 17599  71.2833   C85        C     Mrs         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss         1
# 3      0            113803  53.1000  C123        S     Mrs         2
# 4      0            373450   8.0500   NaN        S      Mr         2

# %% [markdown]
# 나이 구간별 건수 확인

# %%
train_data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_29c76_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_29c76_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_29c76_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_29c76_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_29c76_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_29c76_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Age_band</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29c76_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_29c76_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_29c76_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_29c76_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
#       <th id="T_29c76_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_29c76_row2_col0" class="data row2 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_29c76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29c76_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_29c76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29c76_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 신규로 추가된 파생변수로 분포를 확인해본다

# %%
sns.factorplot('Age_band','Survived',data=train_data,col='Pclass')
plt.show()

# %% [markdown]
# • SibSp : 타이타닉 호에 동승한 자매 / 배우자의 수
# • Parch : 타이타닉 호에 동승한 부모 / 자식의 수
#
# Family_size = sibsp + parch
# Alone = Family_size가 0이면 1, 그렇지 않은 0으로 생성

# %%
# train_data를 Family_Size와 Alone으로 분류

#family size
train_data['Family_Size']=0
train_data['Family_Size']=train_data['Parch']+train_data['SibSp']

# %%
#Alone
train_data['Alone']=0
train_data.loc[train_data.Family_Size==0,'Alone']=1

# %%
sns.factorplot('Family_Size','Survived',data=train_data)
plt.show()

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial  Age_band  \
# 0      0         A/5 21171   7.2500   NaN        S      Mr         1
# 1      0          PC 17599  71.2833   C85        C     Mrs         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss         1
# 3      0            113803  53.1000  C123        S     Mrs         2
# 4      0            373450   8.0500   NaN        S      Mr         2
#
#    Family_Size  Alone
# 0            1      0
# 1            1      0
# 2            0      1
# 3            1      0
# 4            0      1

# %% [markdown]
# 범주형 데이터의 수치형 데이터로 변환

# %%
train_data['Sex'].replace(['male','female'],[0,1],inplace=True)
train_data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
train_data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Initial  Age_band  Family_Size  \
# 0         A/5 21171   7.2500   NaN         0        0         1            1
# 1          PC 17599  71.2833   C85         1        1         2            1
# 2  STON/O2. 3101282   7.9250   NaN         0        2         1            0
# 3            113803  53.1000  C123         0        1         2            1
# 4            373450   8.0500   NaN         0        0         2            0
#
#    Alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# 불필요 변수 제거

# %%
train_data.drop(['Name','Age','Ticket','Cabin','PassengerId','SibSp','Parch'],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex     Fare  Embarked  Initial  Age_band  Family_Size  \
# 0         0       3    0   7.2500         0        0         1            1
# 1         1       1    1  71.2833         1        1         2            1
# 2         1       3    1   7.9250         0        2         1            0
# 3         1       1    1  53.1000         0        1         2            1
# 4         0       3    0   8.0500         0        0         2            0
#
#    Alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# 상관관계 확인

# %%
sns.heatmap(train_data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# 다음 실습에 사용하기위한 저장

# %%
train_data.to_csv('drive/MyDrive/data/p_train.csv', index=False)
test_data.to_csv('drive/MyDrive/data/p_test.csv', index=False)

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex     Fare  Embarked  Initial  Age_band  Family_Size  \
# 0         0       3    0   7.2500         0        0         1            1
# 1         1       1    1  71.2833         1        1         2            1
# 2         1       3    1   7.9250         0        2         1            0
# 3         1       1    1  53.1000         0        1         2            1
# 4         0       3    0   8.0500         0        0         2            0
#
#    Alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
train_data.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Sex            0
# Fare           0
# Embarked       0
# Initial        0
# Age_band       0
# Family_Size    0
# Alone          0
# dtype: int64
